# %% [markdown]
# 1. Import required libraries and read the provided dataset (youtube_dislike_dataset.csv) and retrieve top 5 and bottom 5 records.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import calendar

# %%
jk = pd.read_csv("youtube_dislike_dataset.csv")

# %%
jk
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title         published_at  \
# ...

# %%
jk.head()
# Out:
#       video_id                                       title  \
# 0  --0bCF-iK2E        Jadon Sancho  Magical Skills & Goals
# 1  --14w5SOEUs          Migos - Avalanche (Official Video)
# 2  --40TEbZ9Is  Supporting Actress in a Comedy: 73rd Emmys
# 3  --4tfbSyYDE     JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4  --DKkzWVh-E                Why Retaining Walls Collapse
#
#                  channel_id          channel_title         published_at  \
# 0  UC6UL29enLNe4mqwTfAyeNuw             Bundesliga  2021-07-01 10:00:00
# 1  UCGIelM2Dj3zza3xyV3pL3WQ              MigosVEVO  2021-06-10 16:00:00
# 2  UClBKH8yZRcM4AsRjDVEdjMg     Television Academy  2021-09-20 01:03:32
# 3  UCsmXiDP8S40uBeJYxvyulmA                    JO1  2021-03-03 10:00:17
# 4  UCMOqf8ab-42UUQIdVoKwjlQ  Practical Engineering  2021-12-07 13:00:00
#
#    view_count   likes  dislikes  comment_count  \
# 0     1048888   19515       226           1319
# 1    15352638  359277      7479          18729
# ...

# %%
jk.tail()
# Out:
#           video_id                                              title  \
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id      channel_title         published_at  \
# 37417  UCEB4a5o_6KfjxHwNMnmj54Q           Lil Tjay  2021-02-12 05:03:49
# 37418  UCWJ2lWNubArHWmf3FIHbfcQ                NBA  2021-01-16 05:39:05
# 37419  UCuhAUMLzJxlP1W7mEk0_6lA            MAMAMOO  2021-06-02 09:00:10
# 37420  UC8NjnNWMsRqq11NYvHAQb1g     Master Podcast  2020-10-20 20:59:30
# 37421  UCEg25rdRZXg32iwai6N6l0w  Tottenham Hotspur  2021-05-23 21:00:31
#
#        view_count    likes  dislikes  comment_count  \
# 37417   120408275  2180780     35871          81360
# ...

# %% [markdown]
# 2. Check the info of the dataframe and write your inferences on data types and shape of the dataset.

# %%
jk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37422 entries, 0 to 37421
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   video_id       37422 non-null  object
#  1   title          37422 non-null  object
#  2   channel_id     37422 non-null  object
#  3   channel_title  37422 non-null  object
#  4   published_at   37422 non-null  object
#  5   view_count     37422 non-null  int64
#  6   likes          37422 non-null  int64
#  7   dislikes       37422 non-null  int64
#  8   comment_count  37422 non-null  int64
#  9   tags           37422 non-null  object
#  10  description    37422 non-null  object
#  11  comments       37264 non-null  object
# dtypes: int64(4), object(8)
# memory usage: 3.4+ MB

# %%
jk.dtypes
# Out:
# video_id         object
# title            object
# channel_id       object
# channel_title    object
# published_at     object
# view_count        int64
# likes             int64
# dislikes          int64
# comment_count     int64
# tags             object
# description      object
# comments         object
# dtype: object

# %%
jk.shape
# Out:
# (37422, 12)

# %% [raw]
# inferences:-
# (i)in the datset contain 12 rows and 37422 columns
# (ii)in that 4 columns contain integer data remaining of 8 is object
# (iii)memory usage: 3.4+ MB
# (iv)shape of the dataset is (37422, 12)

# %% [markdown]
#  3. Check for the Percentage of the missing values and drop or impute them.

# %%
jk.isnull().sum()/100
# Out:
# video_id         0.00
# title            0.00
# channel_id       0.00
# channel_title    0.00
# published_at     0.00
# view_count       0.00
# likes            0.00
# dislikes         0.00
# comment_count    0.00
# tags             0.00
# description      0.00
# comments         1.58
# dtype: float64

# %%
df=jk[['comments']].mode()

# %%
jk.dropna(inplace=True)
jk
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title         published_at  \
# ...

# %% [markdown]
# 4. Check the statistical summary of both numerical and categorical columns and write your inferences.

# %%
jk.describe()
# Out:
#          view_count         likes      dislikes  comment_count
# count  3.726400e+04  3.726400e+04  3.726400e+04   3.726400e+04
# mean   5.710821e+06  1.672867e+05  4.996434e+03   9.966953e+03
# std    2.431304e+07  5.384931e+05  3.075194e+04   1.173465e+05
# min    2.036800e+04  2.200000e+01  3.000000e+00   1.000000e+00
# 25%    5.141305e+05  1.331725e+04  2.827500e+02   9.140000e+02
# 50%    1.321860e+06  4.255600e+04  7.980000e+02   2.347000e+03
# 75%    3.674527e+06  1.309665e+05  2.466250e+03   6.212000e+03
# max    1.322797e+09  3.183768e+07  2.397733e+06   1.607103e+07

# %% [raw]
#  inferences:-
#  (i)The describe() method returns description of the data in the DataFrame
#  (ii)count - The number of not-empty values
#  (iii)mean - The average (mean) value
#  (iv)std - The standard deviation
#  (v)min - the minimum value
#  (vi)25% - The 25% percentile*
#  (vii)50% - The 50% percentile*
#  (viii)75% - The 75% percentile*
#  (ix)max - the maximum value

# %% [markdown]
# 5. Convert datatype of column published_at from object to pandas datetime.

# %%
jk['published_at'] = pd.to_datetime(jk['published_at'])
jk.dtypes
# Out:
# video_id                   object
# title                      object
# channel_id                 object
# channel_title              object
# published_at       datetime64[ns]
# view_count                  int64
# likes                       int64
# dislikes                    int64
# comment_count               int64
# tags                       object
# description                object
# comments                   object
# published_month            object
# dtype: object

# %% [markdown]
# 6. Create a new column as 'published_month' using the column published_at (display the months only)

# %%
jk['published_month']=pd.DatetimeIndex(jk['published_at']).month
jk[['published_at','published_month']]
# Out:
#               published_at  published_month
# 0      2021-07-01 10:00:00                7
# 1      2021-06-10 16:00:00                6
# 2      2021-09-20 01:03:32                9
# 3      2021-03-03 10:00:17                3
# 4      2021-12-07 13:00:00               12
# ...                    ...              ...
# 37417  2021-02-12 05:03:49                2
# 37418  2021-01-16 05:39:05                1
# 37419  2021-06-02 09:00:10                6
# 37420  2020-10-20 20:59:30               10
# 37421  2021-05-23 21:00:31                5
#
# [37264 rows x 2 columns]

# %% [markdown]
# 7. Replace the numbers in the column published_month as names of the months i,e., 1 as 'Jan', 2 as 'Feb' and so on.....

# %%
jk['published_month'].replace({1:"Jan",2:"feb",3:"mar",4:"apr",5:"may",6:"jun",7:"july",8:"aug",9:"sep",10:"oct",11:"nov",12:"dec"},inplace=True)
jk[['published_at','published_month']]
# Out:
#               published_at published_month
# 0      2021-07-01 10:00:00            july
# 1      2021-06-10 16:00:00             jun
# 2      2021-09-20 01:03:32             sep
# 3      2021-03-03 10:00:17             mar
# 4      2021-12-07 13:00:00             dec
# ...                    ...             ...
# 37417  2021-02-12 05:03:49             feb
# 37418  2021-01-16 05:39:05             Jan
# 37419  2021-06-02 09:00:10             jun
# 37420  2020-10-20 20:59:30             oct
# 37421  2021-05-23 21:00:31             may
#
# [37264 rows x 2 columns]

# %% [markdown]
# 8. Find the number of videos published each month and arrange the months in a decreasing order based on the video count.

# %%
sk= jk.groupby(['published_month'])
sk['published_month'].count().sort_values(ascending=False)
# Out:
# published_month
# oct     4976
# sep     4854
# nov     4821
# aug     4250
# dec     3063
# july    2331
# jun     2305
# mar     2248
# feb     2125
# apr     2119
# Jan     2099
# may     2073
# Name: published_month, dtype: int64

# %%
jk.pivot_table(index='published_month',values = 'video_id',aggfunc = 'count').sort_values('video_id',ascending=False)
# Out:
#                  video_id
# published_month
# oct                  4976
# sep                  4854
# nov                  4821
# aug                  4250
# dec                  3063
# july                 2331
# jun                  2305
# mar                  2248
# feb                  2125
# apr                  2119
# Jan                  2099
# may                  2073

# %% [markdown]
# 9. Find the count of unique video_id, channel_id and channel_title.

# %%
unique_video_id = jk["video_id"].nunique()
unique_video_id
# Out:
# 37264

# %%
Unique_channel_id = jk["channel_id"].nunique()
Unique_channel_id
# Out:
# 10891

# %%
Unique_channel_title = jk["channel_title"].nunique()
Unique_channel_title
# Out:
# 10813

# %% [markdown]
# 10. Find the top10 channel names having the highest number of videos in the dataset and the bottom10 having lowest number of videos.

# %%
pivot = jk.pivot_table(index='channel_title',values='video_id',aggfunc='count').sort_values('video_id',ascending=False)

# %%
pivot
# Out:
#                      video_id
# channel_title
# Sky Sports Football       533
# The United Stand          301
# BT Sport                  246
# NBA                       209
# NFL                       162
# ...                       ...
# Kaptain Kuba                1
# Kanye West                  1
# Kannur kitchen              1
# Kannada Cinema              1
# zoom                        1
#
# [10813 rows x 1 columns]

# %%
pivot.head(10)
# Out:
#                      video_id
# channel_title
# Sky Sports Football       533
# The United Stand          301
# BT Sport                  246
# NBA                       209
# NFL                       162
# WWE                       122
# SSSniperWolf               99
# SSundee                    98
# FORMULA 1                  87
# NHL                        86

# %%
pivot.tail(10)
# Out:
#                  video_id
# channel_title
# Karikku Tuned           1
# Karen Bustillos         1
# Karen Aslanyan          1
# Karchez                 1
# Karate Combat           1
# Kaptain Kuba            1
# Kanye West              1
# Kannur kitchen          1
# Kannada Cinema          1
# zoom                    1

# %% [markdown]
# 11. Find the title of the video which has the maximum number of likes and the title of the video having minimum likes and write your inferences.

# %%
jk[jk['likes']==jk['likes'].max()][['title','likes']]
# Out:
#                                title     likes
# 26143  BTS () 'Dynamite' Official MV  31837675

# %%
jk[jk['likes']==jk['likes'].min()][['title','likes']]
# Out:
#                                title  likes
# 23855  Leading the Charge | Circle K     22

# %% [raw]
# inferences:-
# (i)max like was given for 'Dynamite' Official MV
# count of like is "31837675"
# (ii)minimum like was give for Leading the Charge | Circle K
# count of like is "22"

# %% [markdown]
# 12. Find the title of the video which has the maximum number of dislikes and the title of the video having minimum dislikes and write your inferences.

# %%
jk[jk['dislikes']==jk['dislikes'].max()][['title','dislikes']]
# Out:
#                                      title  dislikes
# 13591  Cuties | Official Trailer | Netflix   2397733

# %%
jk[jk['dislikes']==jk['dislikes'].min()][['title','dislikes']]
# Out:
#                                         title  dislikes
# 29482  Tims For Good: A Taste Of The Familiar         3

# %%
inferences:-
(i)max dislike was given for Cuties | Official Trailer | Netflix 
count of like is "2397733"
(ii)minimum dislike was give for Tims For Good: A Taste Of The Familiar
count of like is "3"

# %% [markdown]
# 13. Does the number of views have any effect on how many people disliked the video? Support your answer with a metric and a plot.

# %%
new =jk[['view_count','dislikes']]
new.corr()
# Out:
#             view_count  dislikes
# view_count    1.000000  0.684576
# dislikes      0.684576  1.000000

# %%
new.cov()
# Out:
#               view_count      dislikes
# view_count  5.911238e+14  5.118389e+11
# dislikes    5.118389e+11  9.456817e+08

# %%
plt.scatter(new['view_count'],new['dislikes'])
plt.xlabel('view_count')
plt.ylabel('dislikes')
plt.show()

# %% [markdown]
# 14. Display all the information about the videos that were published in January, and mention the count of videos that were published in January.

# %%
jk[jk['published_month']=='Jan']
# Out:
#           video_id                                              title  \
# 27     -2Gwm7QfBnE                                    Q&A With Naisha
# 48     -4sfXSHSxzA           SURPRISING BRENT WITH HIS TIKTOK CRUSH!!
# 95     -AJD1Fc5rpQ  WE ARE HAVING A BABY! | finding out i'm pregna...
# 103    -AuJiwjsmWk              Do Ugly Foods Taste Worse? Taste Test
# 182    -JhqO2KWr5U                                   Schlatt gets fit
# ...            ...                                                ...
# 37300  zmzFL5bG-jc  DEVINE MON PERSONNAGE AVANT AKINATOR ! (c'est ...
# 37329  zpzjex7qwrA  Lampard Sacked Within Days Rorys Misery | Chel...
# 37345  zqyv-B6mnBM                 Lil Wayne - Ain't Got Time (Audio)
# 37383  zwfu1-24T7Q  PRADA Cup Day 1 | Full Race Replay | PRADA Cup...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
#
#                      channel_id       channel_title         published_at  \
# ...

# %%
jk[jk['published_month']=='Jan'].count()['published_month']
# Out:
# 2099
